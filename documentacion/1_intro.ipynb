# %% [markdown]
# # Introduccion
#
# Curso de Fast-API: path operations, validaciones, y autenticacion
#
# Instructo: Pablo España

# %% [markdown]
# ## ¿Que es Fast API?
#
# Es un framewokr moderno y de alto rendimiento para creacion de API con Python.
#
# - rapido
# - menos errores
# - facil e intuitivo
# - robusto: documentacion auto generada
# - basado en estandares
#
# Creado por el colombiano Sebastian Ramirez @tiangolo en el 2018. Usado por:
#
# FastApi fue tomando lo mejor del ecosisitema de Python como:
#
# - Starlette: framework asincrono para construccion de servicios
#
# - Pydantic: validacion de datos
#
# - Uvicorn

# %% [markdown]
# ## Instalación de FastAPI y creación de tu primera aplicación
#
# Crearemos una carpeta llamada *my-movie-api*, y dentro el entorno virtual, el *requirements.txt*, etc, etc
#
# ### Creando el entorno virtual:
#
# Con calquiera de estos dos comandos:
#
# ```sh
# virtualenv env
# python -m venv env
# ```
#
# - Instalamos las dependencias
#
# ### creando la aplicacion
#
# Con un codigo muy basico
#
# ```python
# from fastapi import FastAPI
#
# # creando una instancia de FastAPI
# app = FastAPI()
#
# # Primer END POINT
# @app.get('/')
# def message():
#     return {"saludo":"hola"}
# ```
#
# Asegurate de levantar el servicio usando la bandera *reload* para recargar automaticamente cada vez haya un cambio.
#
#     uvicorn main:app --reload
#
# Observa el localhost:8000 siendo este puerto por defecto.
#
# ### Cambiando el puerto
# ```sh
# uvicorn main:app --reload --port 5000
# ```
#
# Otra configuracion interesante seria no solo ejecutarla localmente, sino en red, por ejemplo accederla dentro de una LAN desde nuestro disposito movil
#
# ```sh
# uvicorn main:app --reload --port 5000 --host 0.0.0.0
# ```

# %% [markdown]
# ## Documentación automática con Swagger
#
# Como acceder: añade a la URL /docs:
#
#     localhost:5000/docs
#
# ![](https://i.imgur.com/OCe2Vox.png)
#
# Podemos observar solo tenemos la ruta raiz, donde solo esta implementado el metodo GET.
#
# Tambien podemos probar cada una de las rutas:
#
# ![](https://i.imgur.com/RaaQbrY.png)

# %% [markdown]
# ### Cambiando el titulo y la version
#
# Tambien la palabrita que dice *dafault* a *home*
#
# ```python
# from fastapi import FastAPI
#
# # creando una instancia de FastAPI
# app = FastAPI()
# app.title = "Mi aplicacion con FastAPI" 👈
# app.version = "0.0.1"
#
# ```
#
# Esta *tags*, nos permitira mas adelante agrupar rutas.
#
# ![](https://i.imgur.com/l70sexr.png)

# %% [markdown]
# ## Métodos HTTP en FastAPI
#
# ### Métodos HTTP
#
# El protocolo HTTP es aquel que define un conjunto de métodos de petición que indican la acción que se desea realizar para un recurso determinado del servidor.
#
# Los principales métodos soportados por HTTP y por ello usados por una API REST son:
#
# - POST: crear un recurso nuevo.
#
# - PUT: modificar un recurso existente.
#
# - GET: consultar información de un recurso.
#
# - DELETE: eliminar un recurso.
#
# Como te diste cuenta con estos métodos podemos empezar a crear un CRUD en nuestra aplicación.
#
# ### ¿De qué tratará nuestra API?
#
# El proyecto que estaremos construyendo a lo largo del curso será una API que nos brindará información relacionada con películas, por lo que tendremos lo siguiente:
#
# #### Consulta de todas las películas
#
# Para lograrlo utilizaremos el método GET y solicitaremos todos los datos de nuestras películas.
#
# #### Filtrado de películas
#
# También solicitaremos información de películas por su id y por la categoría a la que pertenecen, para ello utilizaremos el método GET y nos ayudaremos de los parámetros de ruta y los parámetros query.
#
# #### Registro de peliculas
#
# Usaremos el método POST para registrar los datos de nuestras películas y también nos ayudaremos de los esquemas de la librería pydantic para el manejo de los datos.
#
# #### Modificación y eliminación
#
# Finalmente para completar nuestro CRUD realizaremos la modificación y eliminación de datos en nuestra aplicación, para lo cual usaremos los métodos PUT y DELETE respectivamente.
#
# Y lo mejor es que todo esto lo estarás construyendo mientras aprendes FastAPI, te veo en la siguiente clase donde te enseñaré cómo puedes utilizar el método GET.
